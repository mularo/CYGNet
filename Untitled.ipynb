# %%
import moxing as mox
mox.file.copy_parallel(src_url='obs://20221003/CyGNet/CyGNet-master/', dst_url="./CYGNet")
# Out:
# INFO:root:Using MoXing-v2.1.0.5d9c87c8-5d9c87c8
# INFO:root:Using OBS-Python-SDK-3.20.9.1

# %%
import os
import sys
sys.path.insert(1,'/home/ma-user/work/CYGNet/')  #加入路径
import numpy as np

# %%
# !python CYGNet/get_historical_vocabulary.py --dataset YAGO
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='YAGO', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# 100%|█████████████████████████████████████████| 178/178 [00:12<00:00, 13.72it/s]

# %%
# !python CYGNet/train.py --dataset YAGO --entity object --time-stamp 24 --alpha 0.8 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0
# Out:
# Namespace(alpha=0.8, batch_size=1024, counts=4, dataset='YAGO', entity='object', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=24, valid_epoch=5)
# num_times 8
# 0	177
# 1	177
# 2	177
# 3	177
# 4	177
# 5	177
# 6	177
# 7	177
# 8	177
# 9	177
# 10	177
# 11	177
# 12	177
# 13	177
# 14	177
# 15	177
# 16	177
# 17	177
# 18	177
# 19	177
# 20	177
# 21	177
# 22	177
# 23	177
# 24	177
# 25	177
# 26	177
# 27	177
# 28	177
# 29	177
# 30	177
# 31	177
# 32	177
# 33	177
# 34	177
# 35	177
# 36	177
# 37	177
# 38	177
# 39	177
# 40	177
# 41	177
# 42	177
# 43	177
# 44	177
# 45	177
# 46	177
# 47	177
# 48	177
# 49	177
# 50	177
# 51	177
# 52	177
# 53	177
# 54	177
# 55	177
# 56	177
# 57	177
# 58	177
# 59	177
# 60	177
# 61	177
# 62	177
# 63	177
# 64	177
# 65	177
# 66	177
# 67	177
# 68	177
# 69	177
# 70	177
# 71	177
# 72	177
# 73	177
# 74	177
# 75	177
# 76	177
# 77	177
# 78	177
# 79	177
# 80	177
# 81	177
# 82	177
# 83	177
# 84	177
# 85	177
# 86	177
# 87	177
# 88	177
# ...

# %%
# !python CYGNet/get_historical_vocabulary.py --dataset ICEWS18
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='ICEWS18', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# 100%|█████████████████████████████████████████| 240/240 [01:48<00:00,  2.22it/s]

# %%
# !python CYGNet/train.py --dataset ICEWS18 --entity object --time-stamp 24 --alpha 0.8 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0
# Out:
# Namespace(alpha=0.8, batch_size=1024, counts=4, dataset='ICEWS18', entity='object', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=24, valid_epoch=5)
# num_times 304
# 0	5736
# 24	5736
# 48	5736
# 72	5736
# 96	5736
# 120	5736
# 144	5736
# 168	5736
# 192	5736
# 216	5736
# 240	5736
# 264	5736
# 288	5736
# 312	5736
# 336	5736
# 360	5736
# 384	5736
# 408	5736
# 432	5736
# 456	5736
# 480	5736
# 504	5736
# 528	5736
# 552	5736
# 576	5736
# 600	5736
# 624	5736
# 648	5736
# 672	5736
# 696	5736
# 720	5736
# 744	5736
# 768	5736
# 792	5736
# 816	5736
# 840	5736
# 864	5736
# 888	5736
# 912	5736
# 936	5736
# 960	5736
# 984	5736
# 1008	5736
# 1032	5736
# 1056	5736
# 1080	5736
# 1104	5736
# 1128	5736
# 1152	5736
# 1176	5736
# 1200	5736
# 1224	5736
# 1248	5736
# 1272	5736
# 1296	5736
# 1320	5736
# 1344	5736
# 1368	5736
# 1392	5736
# 1416	5736
# 1440	5736
# 1464	5736
# 1488	5736
# 1512	5736
# 1536	5736
# 1560	5736
# 1584	5736
# 1608	5736
# 1632	5736
# ...

# %% [markdown]
# #10.22

# %%
# !python CYGNet/get_historical_vocabulary.py --dataset WIKI
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='WIKI', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# 100%|█████████████████████████████████████████| 211/211 [00:43<00:00,  4.88it/s]

# %%
# !python CYGNet/train.py --dataset WIKI --entity object --time-stamp 24 --alpha 0.8 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0
# Out:
# Namespace(alpha=0.8, batch_size=1024, counts=4, dataset='WIKI', entity='object', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=24, valid_epoch=5)
# num_times 10
# 0	210
# 1	210
# 2	210
# 3	210
# 4	210
# 5	210
# 6	210
# 7	210
# 8	210
# 9	210
# 10	210
# 11	210
# 12	210
# 13	210
# 14	210
# 15	210
# 16	210
# 17	210
# 18	210
# 19	210
# 20	210
# 21	210
# 22	210
# 23	210
# 24	210
# 25	210
# 26	210
# 27	210
# 28	210
# 29	210
# 30	210
# 31	210
# 32	210
# 33	210
# 34	210
# 35	210
# 36	210
# 37	210
# 38	210
# 39	210
# 40	210
# 41	210
# 42	210
# 43	210
# 44	210
# 45	210
# 46	210
# 47	210
# 48	210
# 49	210
# 50	210
# 51	210
# 52	210
# 53	210
# 54	210
# 55	210
# 56	210
# 57	210
# 58	210
# 59	210
# 60	210
# 61	210
# 62	210
# 63	210
# 64	210
# 65	210
# 66	210
# 67	210
# 68	210
# 69	210
# 70	210
# 71	210
# 72	210
# 73	210
# 74	210
# 75	210
# 76	210
# 77	210
# 78	210
# 79	210
# 80	210
# 81	210
# 82	210
# 83	210
# 84	210
# 85	210
# 86	210
# 87	210
# 88	210
# ...

# %%
# !python train.py --dataset YAGO --entity subject --time-stamp 1 --alpha 0.5 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0 --batch-size 1024 --counts 4 --valid-epoch 5
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='YAGO', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 189
# 0	177
# 1	177
# 2	177
# 3	177
# 4	177
# 5	177
# 6	177
# 7	177
# 8	177
# 9	177
# 10	177
# 11	177
# 12	177
# 13	177
# 14	177
# 15	177
# 16	177
# 17	177
# 18	177
# 19	177
# 20	177
# 21	177
# 22	177
# 23	177
# 24	177
# 25	177
# 26	177
# 27	177
# 28	177
# 29	177
# 30	177
# 31	177
# 32	177
# 33	177
# 34	177
# 35	177
# 36	177
# 37	177
# 38	177
# 39	177
# 40	177
# 41	177
# 42	177
# 43	177
# 44	177
# 45	177
# 46	177
# 47	177
# 48	177
# 49	177
# 50	177
# 51	177
# 52	177
# 53	177
# 54	177
# 55	177
# 56	177
# 57	177
# 58	177
# 59	177
# 60	177
# 61	177
# 62	177
# 63	177
# 64	177
# 65	177
# 66	177
# 67	177
# 68	177
# 69	177
# 70	177
# 71	177
# 72	177
# 73	177
# 74	177
# 75	177
# 76	177
# 77	177
# 78	177
# 79	177
# 80	177
# 81	177
# 82	177
# 83	177
# 84	177
# 85	177
# 86	177
# 87	177
# 88	177
# ...

# %%
# !python get_historical_vocabulary.py --dataset GDELT
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='GDELT', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# 100%|███████████████████████████████████████| 2138/2138 [22:39<00:00,  1.57it/s]

# %%
# !python train.py --dataset GDELT  --time-stamp 15 --lr 0.001 --n-epoch 30 --hidden-dim 200 --valid-epoch 1 --alpha 0.7  --counts 2

# %%
 # !python test.py --dataset WIKI
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='WIKI', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 232
#
# start object testing:
# Using best epoch: 8
# test object-- Epoch 0008 | Best MRR 0.5275 | Hits@1 0.5091 | Hits@3 0.5390 | Hits@10 0.5502
#
# start subject testing:
# Using best epoch: 8
# test subject-- Epoch 0008 | Best MRR 0.3516 | Hits@1 0.2882 | Hits@3 0.3943 | Hits@10 0.4736
#
#
# final test --| Best MRR 0.4396 | Hits@1 0.3986 | Hits@3 0.4667 | Hits@10 0.5119
# end

# %%
# !python test.py --dataset YAGO
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='YAGO', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 189
#
# start object testing:
# Using best epoch: 13
# test object-- Epoch 0013 | Best MRR 0.6681 | Hits@1 0.6436 | Hits@3 0.6788 | Hits@10 0.7056
#
# start subject testing:
# Using best epoch: 13
# test subject-- Epoch 0013 | Best MRR 0.6001 | Hits@1 0.5534 | Hits@3 0.6315 | Hits@10 0.6754
#
#
# final test --| Best MRR 0.6341 | Hits@1 0.5985 | Hits@3 0.6551 | Hits@10 0.6905
# end

# %%
import os
print(os.path.abspath('.'))
# Out:
# /home/ma-user/work/CYGNet

# %%
# !python test.py --dataset ICEWS18
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='ICEWS18', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 7273
#
# start object testing:
# Using best epoch: 6
# test object-- Epoch 0006 | Best MRR 0.4558 | Hits@1 0.3888 | Hits@3 0.4895 | Hits@10 0.5736
#
# start subject testing:
# Using best epoch: 6
# test subject-- Epoch 0006 | Best MRR 0.3845 | Hits@1 0.3572 | Hits@3 0.4079 | Hits@10 0.4228
#
#
# final test --| Best MRR 0.4202 | Hits@1 0.3730 | Hits@3 0.4487 | Hits@10 0.4982
# end

# %%
# !python get_historical_vocabulary.py --dataset ICEWS14
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='ICEWS14', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# 100%|█████████████████████████████████████████| 181/181 [00:54<00:00,  3.32it/s]

# %%
 # !python train.py --dataset ICEWS14 --entity object --time-stamp 24 --alpha 0.8 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0 --batch-size 1024 --counts 4 --valid-epoch 5
# Out:
# Namespace(alpha=0.8, batch_size=1024, counts=4, dataset='ICEWS14', entity='object', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=24, valid_epoch=5)
# num_times 365
# 0	4320
# 24	4320
# 48	4320
# 72	4320
# 96	4320
# 120	4320
# 144	4320
# 168	4320
# 192	4320
# 216	4320
# 240	4320
# 264	4320
# 288	4320
# 312	4320
# 336	4320
# 360	4320
# 384	4320
# 408	4320
# 432	4320
# 456	4320
# 480	4320
# 504	4320
# 528	4320
# 552	4320
# 576	4320
# 600	4320
# 624	4320
# 648	4320
# 672	4320
# 696	4320
# 720	4320
# 744	4320
# 768	4320
# 792	4320
# 816	4320
# 840	4320
# 864	4320
# 888	4320
# 912	4320
# 936	4320
# 960	4320
# 984	4320
# 1008	4320
# 1032	4320
# 1056	4320
# 1080	4320
# 1104	4320
# 1128	4320
# 1152	4320
# 1176	4320
# 1200	4320
# 1224	4320
# 1248	4320
# 1272	4320
# 1296	4320
# 1320	4320
# 1344	4320
# 1368	4320
# 1392	4320
# 1416	4320
# 1440	4320
# 1464	4320
# 1488	4320
# 1512	4320
# 1536	4320
# 1560	4320
# 1584	4320
# 1608	4320
# 1632	4320
# ...

# %%
# !python test.py --dataset ICEWS14
#出现问题是因为在预测客体时找不到模型，因为没有训练客体！再训练一次需要十个小时左右，就直接自己创建一个用主题训练的模型来预测客体吧，
                                                                                    # 后来发现效果也不错
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='ICEWS14', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 8737
#
# start object testing:
# Using best epoch: 6
# test object-- Epoch 0006 | Best MRR 0.4697 | Hits@1 0.3899 | Hits@3 0.5144 | Hits@10 0.6108
#
# start subject testing:
# Traceback (most recent call last):
#   File "test.py", line 105, in <module>
#     checkpoint_sub = torch.load(model_state_file_sub)
#   File "/home/ma-user/anaconda3/envs/PyTorch-1.8/lib/python3.7/site-packages/torch/serialization.py", line 579, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/ma-user/anaconda3/envs/PyTorch-1.8/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/home/ma-user/anaconda3/envs/PyTorch-1.8/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
# Out:
# True
# 1
# 0

# %%
torch.cuda.device_count()
torch.cuda.current_device()
# Out:
# 0

# %%
# !python train.py --dataset GDELT --entity object --time-stamp 15 --alpha 0.7 --lr 0.001 --n-epoch 30 --hidden-dim 200 --gpu 0 --batch-size 1024 --valid-epoch 1
# Out:
# Namespace(alpha=0.7, batch_size=1024, counts=2, dataset='GDELT', entity='object', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=15, valid_epoch=1)
# num_times 2976
# 0	34545
# 15	34545
# 30	34545
# 45	34545
# 60	34545
# 75	34545
# 90	34545
# 105	34545
# 120	34545
# 135	34545
# 150	34545
# 165	34545
# 180	34545
# 195	34545
# 210	34545
# 225	34545
# 240	34545
# 255	34545
# 270	34545
# 285	34545
# 300	34545
# 315	34545
# 330	34545
# 345	34545
# 360	34545
# 375	34545
# 390	34545
# 405	34545
# 420	34545
# 435	34545
# 450	34545
# 480	34545
# 495	34545
# 510	34545
# 525	34545
# 540	34545
# 555	34545
# 570	34545
# 585	34545
# 600	34545
# 615	34545
# 630	34545
# 645	34545
# 660	34545
# 675	34545
# 690	34545
# 705	34545
# 720	34545
# 735	34545
# 750	34545
# 765	34545
# 780	34545
# 795	34545
# 810	34545
# 825	34545
# 840	34545
# 855	34545
# 870	34545
# 885	34545
# 900	34545
# 915	34545
# 930	34545
# 945	34545
# 960	34545
# 975	34545
# 990	34545
# ...

# %%
# !python test.py --dataset GDELT
# Out:
# Namespace(alpha=0.5, batch_size=1024, counts=4, dataset='GDELT', entity='subject', gpu=0, hidden_dim=200, lr=0.001, n_epochs=30, raw=False, regularization=0.01, time_stamp=1, valid_epoch=5)
# num_times 44626
#
# start object testing:
# Using best epoch: 2
# test object-- Epoch 0002 | Best MRR 0.4789 | Hits@1 0.4018 | Hits@3 0.5242 | Hits@10 0.6108
#
# start subject testing:
# Using best epoch: 2
